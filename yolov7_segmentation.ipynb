# %% [markdown]
# <a href="https://colab.research.google.com/github/chelsea456/detectron2_motor/blob/main/yolov7_segmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/chelsea456/yolov7_mask.git
# Out:
# Cloning into 'yolov7_mask'...
# remote: Enumerating objects: 118, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 118 (delta 0), reused 0 (delta 0), pack-reused 112
# Receiving objects: 100% (118/118), 843.26 KiB | 20.57 MiB/s, done.
# Resolving deltas: 100% (16/16), done.

# %%
# !cd yolov7_mask

# %%
# !cd yolov7_mask/

# %%
# !pip install -r /content/yolov7_mask/yolov7_mask/requirements.txt

# %%
# !python /content/yolov7_mask/yolov7_mask/train.py --data /content/yolov7_mask/yolov7_mask/data/coco.yaml --batch 16  --cfg yolov7-seg.yaml --epochs 30 --name yolov7-seg --img 640 --hyp hyp.scratch-high.yaml
# Out:
# train: weights=yolov7_mask/yolov5s-seg.pt, cfg=yolov7-seg.yaml, data=/content/yolov7_mask/yolov7_mask/data/coco.yaml, hyp=hyp.scratch-high.yaml, epochs=30, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=yolov7_mask/runs/train-seg, name=yolov7-seg, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, mask_ratio=4, no_overlap=False
# YOLOv5 🚀 2022-9-4 Python-3.7.13 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# ...
